# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cgpa_salary_dataset.csv')

# %%
df.head()
# Out:
#    CGPA  Experience  Attendance  Backlogs  LPA
# 0   7.2         0.0          75         2  3.5
# 1   8.1         1.0          82         1  5.2
# 2   6.8         0.0          70         3  2.8
# 3   9.0         2.0          90         0  9.5
# 4   8.5         1.5          88         0  7.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CGPA        49 non-null     float64
#  1   Experience  49 non-null     float64
#  2   Attendance  49 non-null     int64
#  3   Backlogs    49 non-null     int64
#  4   LPA         49 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 2.0 KB

# %%
x = df[["CGPA", "Experience", "Attendance", "Backlogs"]]
y = df["LPA"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 40)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE:", mse)
print("R2 Score:", r2)
# Out:
# MSE: 0.05617043311100086
# R2 Score: 0.9966324882278284

# %%
coeff_df = pd.DataFrame(model.coef_, x.columns, columns=["Coefficient"])
print(coeff_df)

print("Intercept:", model.intercept_)
# Out:
#             Coefficient
# CGPA           1.135927
# Experience     1.835857
# Attendance     0.024402
# Backlogs       0.064647
# Intercept: -7.073026893606695

# %%
custom_input = np.array([[8.5, 1.5, 85, 1]])

predicted_salary = model.predict(custom_input)
print("Predicted Salary (LPA):", predicted_salary[0])
# Out:
# Predicted Salary (LPA): 7.474965712184895
# /home/ankit/.local/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
custom_input = np.array([[8.5, 1.5, 85, 3]])

predicted_salary = model.predict(custom_input)
print("Predicted Salary (LPA):", predicted_salary[0])
# Out:
# Predicted Salary (LPA): 7.604259928645185
# /home/ankit/.local/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
